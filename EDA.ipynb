# %%
from utils.data_helper import EDA
import pandas as pd
from utils.image_helper import DataAdapter
import numpy as np

# %%
eda = EDA('data/self-data.csv')

# %% [markdown]
# Transparency (Alpha)

# %%
DA = DataAdapter('data/self-data.csv')
for i in range(0, 1500):
    t = 0
    c = 0
    try:
        name, img, bbox, label = DA.i_get(1)
        num = np.array(img)[55, 22, 3]
        t += 1
        if num != 255: c += 1
    except: pass
print('Percent of images with some transparency (alpha): {}'.format(c/t*100))
# Out:
# Percent of images with some transparency (alpha): 0.0

# %% [markdown]
# Image Distributions (depth is the color channel, where 4th channel is alpha, representing transparency)

# %%
eda.image_dist()

# %% [markdown]
# Bounding Box Distributions

# %%
eda.coord_dist()

# %% [markdown]
# Label Percentage

# %%
eda.label()
# Out:
# Positive: 217 Negative: 1004
# Percent of positives: 17.772317772317773
